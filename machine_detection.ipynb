# %%
# #!git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# !pip install comet_ml
# !pip install clearml
# !pip install roboflow
# !pip install tensorboard
# %cd ..

# %%
import os
import cv2
import torch
import numpy as np

import PIL
from PIL import Image, ImageDraw, ImageFont

# %% [markdown]
# # Train Model

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="4kzpxkyWqyEYaB55naOz")
project = rf.workspace("projecttest").project("machine_detection")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
project_name = "Machine_Detection"

# %% [markdown]
# ## 1. Original

# %%
# %cd dataset
# dataset = project.version(1).download("yolov5")
# %cd ..

# %%
dataset_name = "dataset/machine_detection-1/data.yaml"
task_name = "org_yolov5n"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5n.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=dataset/machine_detection-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=org_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
# !python yolov5/val.py \
    --weights {project_name + "/train/" + task_name + "/weights/best.pt"}  \
    --data {dataset_name} \
    --img 640 \
    --project {project_name + "/val"} \
    --name {task_name}
# Out:
# val: data=dataset/machine_detection-1/data.yaml, weights=['Machine_Detection/train/org_yolov5n/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=Machine_Detection/val, name=org_yolov5n, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1792990 parameters, 0 gradients, 4.2 GFLOPs
# val: Scanning /data/home/mike/advanced_project2/dataset/machine_detection-1/vali
#                  Class     Images  Instances          P          R      mAP50   ^C
#                  Class     Images  Instances          P          R      mAP50
# Traceback (most recent call last):
#   File "yolov5/val.py", line 408, in <module>
#     main(opt)
#   File "yolov5/val.py", line 379, in main
#     run(**vars(opt))
# ...

# %%
dataset_name = "dataset/machine_detection-1/data.yaml"
task_name = "org_yolov5s"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5s.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/machine_detection-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=org_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
# !python yolov5/val.py \
    --weights {project_name + "/train/" + task_name + "/weights/best.pt"}  \
    --data {dataset_name} \
    --img 640 \
    --project {project_name + "/val"} \
    --name {task_name}
# Out:
# val: data=dataset/machine_detection-1/data.yaml, weights=['Machine_Detection/train/org_yolov5s/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=Machine_Detection/val, name=org_yolov5s, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7077550 parameters, 0 gradients, 16.0 GFLOPs
# val: Scanning /data/home/mike/advanced_project2/dataset/machine_detection-1/vali
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 2.100s exceeded
# ...

# %%
dataset_name = "dataset/machine_detection-1/data.yaml"
task_name = "org_yolov5m"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5m.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset/machine_detection-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=org_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-1/data.yaml"
task_name = "org_yolov5l"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5l.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=org_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-1/data.yaml"
task_name = "org_yolov5x"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5x.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=dataset/machine_detection-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=org_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# ## 2. AUG_v1

# %% [markdown]
# - Outputs per training example: 3
# - Crop: 0% Minimum Zoom, 20% Maximum Zoom
# - Rotation: Between -15° and +15°
# - Hue: Between -25° and +25°
# - Exposure: Between -25% and +25%

# %%
# %cd dataset
# dataset = project.version(2).download("yolov5")
# %cd ..
# Out:
# /data/home/mike/advanced_project2/dataset
# ...
# Extracting Dataset Version Zip to machine_detection-2 in yolov5pytorch:: 100%|██████████| 4202/4202 [00:00<00:00, 7977.99it/s]
# /data/home/mike/advanced_project2

# %%
dataset_name = "dataset/machine_detection-2/data.yaml"
task_name = "aug1_yolov5n"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5n.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=dataset/machine_detection-2/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug1_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-2/data.yaml"
task_name = "aug1_yolov5s"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5s.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/machine_detection-2/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug1_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-2/data.yaml"
task_name = "aug1_yolov5m"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5m.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset/machine_detection-2/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug1_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-2/data.yaml"
task_name = "aug1_yolov5l"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5l.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection-2/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug1_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-2/data.yaml"
task_name = "aug1_yolov5x"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5l.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection-2/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug1_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# ## 3. AUG_v2

# %% [markdown]
# - Outputs per training example: 3
# - Grayscale: Apply to 25% of images
# - Saturation: Between -25% and +25%
# - Exposure: Between -25% and +25%
# - Noise: Up to 5% of pixels

# %%
dataset_name = "dataset/machine_detection-4/data.yaml"
task_name = "aug2_yolov5n"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5n.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=dataset/machine_detection-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug2_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-4/data.yaml"
task_name = "aug2_yolov5s"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5s.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/machine_detection-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug2_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-4/data.yaml"
task_name = "aug2_yolov5m"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5m.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset/machine_detection-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug2_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-4/data.yaml"
task_name = "aug2_yolov5l"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5l.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug2_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection-4/data.yaml"
task_name = "aug2_yolov5x"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights yolov5x.pt \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=dataset/machine_detection-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=aug2_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 26 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# # Detect whole machine

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="4kzpxkyWqyEYaB55naOz")
project = rf.workspace("projecttest").project("machine_detection2")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
project_name = "Machine_Detection"

# %% [markdown]
# # 1. Original

# %%
# %cd dataset
# dataset = project.version(1).download("yolov5")
# %cd ..

# %%
dataset_name = "dataset/machine_detection2-1/data.yaml"
weights = "yolov5n"
task_name = f"whole_org_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=dataset/machine_detection2-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-1/data.yaml"
weights = "yolov5s"
task_name = f"whole_org_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/machine_detection2-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-1/data.yaml"
weights = "yolov5m"
task_name = f"whole_org_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset/machine_detection2-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-1/data.yaml"
weights = "yolov5l"
task_name = f"whole_org_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection2-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-1/data.yaml"
weights = "yolov5x"
task_name = f"whole_org_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=dataset/machine_detection2-1/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# # 2. Aug_v1

# %%
# %cd dataset
# dataset = project.version(3).download("yolov5")
# %cd ..
# Out:
# /data/home/mike/advanced_project2/dataset
# ...
# Extracting Dataset Version Zip to machine_detection2-3 in yolov5pytorch:: 100%|██████████| 4202/4202 [00:00<00:00, 9479.11it/s]
# /data/home/mike/advanced_project2

# %%
dataset_name = "dataset/machine_detection2-3/data.yaml"
weights = "yolov5n"
task_name = f"whole_aug1_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=dataset/machine_detection2-3/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug1_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-3/data.yaml"
weights = "yolov5s"
task_name = f"whole_aug1_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/machine_detection2-3/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug1_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-3/data.yaml"
weights = "yolov5m"
task_name = f"whole_org_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset/machine_detection2-3/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-3/data.yaml"
weights = "yolov5l"
task_name = f"whole_aug1_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection2-3/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-3/data.yaml"
weights = "yolov5x"
task_name = f"whole_aug1_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=dataset/machine_detection2-3/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_org_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# # 3. Aug_v2

# %%
# %cd dataset
dataset = project.version(4).download("yolov5")
# %cd ..
# Out:
# [Errno 2] No such file or directory: 'dataset'
# /data/home/mike/advanced_project2/dataset
# ...
# Extracting Dataset Version Zip to machine_detection2-4 in yolov5pytorch:: 100%|██████████| 4202/4202 [00:00<00:00, 8108.32it/s]
# /data/home/mike/advanced_project2

# %%
dataset_name = "dataset/machine_detection2-4/data.yaml"
weights = "yolov5n"
task_name = f"whole_aug2_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=dataset/machine_detection2-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug2_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-4/data.yaml"
weights = "yolov5s"
task_name = f"whole_aug2_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset/machine_detection2-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug2_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-4/data.yaml"
weights = "yolov5m"
task_name = f"whole_aug2_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=dataset/machine_detection2-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug2_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-4/data.yaml"
weights = "yolov5l"
task_name = f"whole_aug2_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=dataset/machine_detection2-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug2_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "dataset/machine_detection2-4/data.yaml"
weights = "yolov5x"
task_name = f"whole_aug2_{weights}"

# !python yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/train"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=dataset/machine_detection2-4/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=Machine_Detection/train, name=whole_aug2_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 45 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v7.0-27-g454dae1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# # Use preprocessing data

# %%
project_name = "detection/results"

# %% [markdown]
# ## Machine

# %%
dataset_name = "detection/dataset/machine_whole/data.yaml"
weights = "yolov5n"
task_name = f"machine_whole_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_whole"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=detection/dataset/machine_whole/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_whole, name=machine_whole_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_whole/data.yaml"
weights = "yolov5s"
task_name = f"machine_whole_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_whole"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=detection/dataset/machine_whole/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_whole, name=machine_whole_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_whole/data.yaml"
weights = "yolov5m"
task_name = f"machine_whole_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_whole"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=detection/dataset/machine_whole/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_whole, name=machine_whole_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_whole/data.yaml"
weights = "yolov5l"
task_name = f"machine_whole_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_whole"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=detection/dataset/machine_whole/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_whole, name=machine_whole_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_whole/data.yaml"
weights = "yolov5x"
task_name = f"machine_whole_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_whole"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=detection/dataset/machine_whole/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_whole, name=machine_whole_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %% [markdown]
# ## Machine Parts

# %%
dataset_name = "detection/dataset/machine_parts/data.yaml"
weights = "yolov5n"
task_name = f"machine_parts_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_part"}\
    --name {task_name}
# Out:
# train: weights=yolov5n.pt, cfg=, data=detection/dataset/machine_parts/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_part, name=machine_parts_yolov5n, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_parts/data.yaml"
weights = "yolov5s"
task_name = f"machine_parts_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_part"}\
    --name {task_name}
# Out:
# train: weights=yolov5s.pt, cfg=, data=detection/dataset/machine_parts/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_part, name=machine_parts_yolov5s, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_parts/data.yaml"
weights = "yolov5m"
task_name = f"machine_parts_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_part"}\
    --name {task_name}
# Out:
# train: weights=yolov5m.pt, cfg=, data=detection/dataset/machine_parts/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_part, name=machine_parts_yolov5m, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_parts/data.yaml"
weights = "yolov5l"
task_name = f"machine_parts_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_part"}\
    --name {task_name}
# Out:
# train: weights=yolov5l.pt, cfg=, data=detection/dataset/machine_parts/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_part, name=machine_parts_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...

# %%
dataset_name = "detection/dataset/machine_parts/data.yaml"
weights = "yolov5x"
task_name = f"machine_parts_{weights}"

# !python detection/yolov5/train.py \
    --img 640 --batch 16 --epochs 3 \
    --bbox_interval 1 \
    --data {dataset_name} \
    --weights {weights + ".pt"} \
    --project {project_name + "/machine_part"}\
    --name {task_name}
# Out:
# train: weights=yolov5x.pt, cfg=, data=detection/dataset/machine_parts/data.yaml, hyp=detection/yolov5/data/hyps/hyp.scratch-low.yaml, epochs=3, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=detection/results/machine_part, name=machine_parts_yolov5x, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-97-gfa4bdbe1 Python-3.8.15 torch-1.13.0+cu117 CPU
#
# ...
